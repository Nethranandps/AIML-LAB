# %% [markdown]
# Demonstrate Genetic algorithm by taking a suitable data for any simple application.

# %%
import random
import string

# %%
# Define constants
TARGET_STRING= "HELLOGENETICALGORITHM"
POPULATION_SIZE =1000
MUTATION_RATE= 0.01
MAX_GENERATIONS= 1000

# %%
# Generate a random string of a given Length
def random_string(length=len (TARGET_STRING)):
    # Join together 'Length' number of random uppercase characters
    return ''.join(random.choice(string.ascii_uppercase) for _ in range (length))

# %%
# Compute how close a string is to the target string
def fitness (individual):
    # Count number of positions where the individual string matches the target string
    return sum(1 for a, b in zip(individual, TARGET_STRING) if a == b)

# %%
# Select a parent string from the population, favoring fitter strings
def select_parent (population):
    # Select and return one individual from the population based on fitness weights
    return random.choices (population, weights=[fitness (ind) for ind in population], k=1)[0]

# %%
# Combine two strings into one
def crossover (parent1, parent2):
    # Randomly choose a split point
    split=random.randint (1, len(TARGET_STRING)-2)
    # Create a new string that's part one parent and part the other
    child=parent1[:split] + parent2[split:]
    return child

# %%
#Make a small random change to a string
def mutate (individual):
    # With a small chance, alter one character in the string
    if random.random() < MUTATION_RATE:
        # Pick a random position in the string
        position=random.randint (0, len(TARGET_STRING)-1)
        # Pick a random uppercase character
        replacement = random.choice(string.ascii_uppercase)
        #Replace the character at the chosen position
        individual = individual[:position] + replacement+ individual[position+1:]
    return individual

# %%
# The main evolution process
def evolve():
    # Create an initial random population of strings
    population= [random_string() for _ in range (POPULATION_SIZE)]
    # For a number of generations...
    for generation in range (MAX_GENERATIONS) :
     # Print the best string in this generation
     print (f"Generation {generation + 1}: Best String: {max (population, key=fitness)}")
      # If we've found the target string, stop
     if max (population, key=fitness) == TARGET_STRING:
        print("Target String reached!")
        break

     # Create a new generation of strings
     new_population = []
     for _ in range (POPULATION_SIZE):
        # Select two parent strings
        parent1= select_parent (population)
        parent2 = select_parent (population)
        # Create a child string by combining the parents.
        child= crossover (parent1, parent2)
        #Possibly mutate the child
        child= mutate (child)
        # Add the child to the new generation
        new_population.append(child)
    
    #Replace the old generation with the new generation 
    population=new_population

# %%
evolve()
# Out:
# Generation 1: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 2: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 3: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 4: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 5: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 6: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 7: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 8: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 9: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 10: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 11: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 12: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 13: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 14: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 15: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 16: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 17: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 18: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 19: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 20: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 21: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 22: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 23: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 24: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 25: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 26: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 27: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 28: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 29: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 30: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 31: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 32: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 33: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 34: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 35: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 36: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 37: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 38: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 39: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 40: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 41: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 42: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 43: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 44: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 45: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 46: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 47: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 48: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 49: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 50: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 51: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 52: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 53: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 54: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 55: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 56: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 57: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 58: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 59: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 60: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 61: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 62: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 63: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 64: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 65: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 66: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 67: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 68: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 69: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 70: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 71: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 72: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 73: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 74: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 75: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 76: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 77: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 78: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 79: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 80: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 81: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 82: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 83: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 84: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 85: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 86: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 87: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 88: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 89: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 90: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 91: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 92: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 93: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 94: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 95: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 96: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 97: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 98: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 99: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 100: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 101: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 102: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 103: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 104: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 105: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 106: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 107: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 108: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 109: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 110: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 111: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 112: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 113: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 114: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 115: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 116: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 117: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 118: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 119: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 120: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 121: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 122: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 123: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 124: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 125: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 126: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 127: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 128: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 129: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 130: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 131: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 132: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 133: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 134: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 135: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 136: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 137: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 138: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 139: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 140: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 141: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 142: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 143: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 144: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 145: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 146: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 147: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 148: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 149: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 150: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 151: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 152: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 153: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 154: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 155: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 156: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 157: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 158: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 159: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 160: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 161: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 162: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 163: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 164: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 165: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 166: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 167: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 168: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 169: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 170: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 171: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 172: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 173: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 174: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 175: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 176: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 177: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 178: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 179: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 180: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 181: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 182: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 183: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 184: Best String: BEEXOEVEWTFWALGGNEIIS
# Generation 185: Best String: BEEXOEVEWTFWALGGNEIIS
